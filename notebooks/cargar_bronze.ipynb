# %%
import sys
import os

sys.path.append(os.path.abspath("../etl"))

import etl1_bronze

etl1_bronze.main()
# Out:
# Importacion OK
# Descargando archivo desde Drive...
# Downloading...
# From: https://drive.google.com/uc?id=1Sk1E7GRJrOfEFh_286utp5jQKmAQBRTV
# To: e:\Repo\ALCOCER_RODRIGUEZ_ALEX\notebooks\ventas_16032026.csv
# 100%|██████████| 947k/947k [00:00<00:00, 2.27MB/s]
# Archivo descargado: ventas_16032026.csv
# Filas: 10000
# Conexion OK
# Carga masiva completada
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 8
#       4 sys.path.append(os.path.abspath("../etl"))
#       6 import etl1_bronze
# ----> 8 etl1_bronze.main()
#
# AttributeError: module 'etl1_bronze' has no attribute 'main'
