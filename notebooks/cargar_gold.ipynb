# %%
import sys
import os
import importlib

sys.path.append(os.path.abspath("../etl"))

import etl3_gold
importlib.reload(etl3_gold)

etl3_gold.main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       3 import importlib
#       5 sys.path.append(os.path.abspath("../etl"))
# ----> 7 import etl3_gold
#       8 importlib.reload(etl3_gold)
#      10 etl3_gold.main()
#
# File e:\Repo\ALCOCER_RODRIGUEZ_ALEX\etl\etl3_gold.py:8
#       6 import pickle
#       7 import io  # 🔥 NUEVO
# ----> 8 from supabase import create_client  # 🔥 NUEVO
#      10 from sklearn.ensemble import RandomForestRegressor
#      12 sys.path.append(os.path.abspath("../.secrets"))
#
# ModuleNotFoundError: No module named 'supabase'
